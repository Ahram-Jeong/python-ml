# %% [markdown]
# ### 네이버 검색 후 뉴스 제목 크롤링
# 1. 크롬 브라우저 열기
# 2. 네이버 접속
# 3. 검색 창 접근 후, 원하는 검색에 입력하여 검색
# 4. 이미지 탭 클릭
# 5. 뒤로가기
# 6. 뉴스 탭 클릭하여 스크롤을 맨 끝으로 내린 후, 뉴스 제목 크롤링
# 7. 크롤링 내용은 DataFrame으로 만들고 파일로 저장
# 8. 뒤로가기를 통해 메인으로 이동
# 9. 브라우저 완전 종료

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time

# %%
driver = wb.Chrome()
driver.get("https://www.naver.com/")
driver.maximize_window()

# 원하는 검색에 입력하여 검색
search = driver.find_element(By.CSS_SELECTOR, "#query")
search.send_keys("뉴진스")
btn = driver.find_element(By.CSS_SELECTOR, "#search-btn")
btn.click()

# 이미지 탭 클릭, 뒤로가기
img = driver.find_element(By.CSS_SELECTOR, ".spnew2.ico_nav_image")
img.click()
time.sleep(2)
driver.back()

# 뉴스 탭 클릭
news = driver.find_element(By.CSS_SELECTOR, ".spnew2.ico_nav_news")
news.click()
# 스크롤 끝으로 내리기
body = driver.find_element(By.TAG_NAME, "body")
body.send_keys(Keys.END)
time.sleep(2)

# 뉴스 제목 크롤링
result = []
naver_news = driver.find_elements(By.CSS_SELECTOR, ".news_tit")
for i in range(len(naver_news)) :
    result.append(naver_news[i].text)
    
news_dic = {"제목" : result}
df = pd.DataFrame(news_dic, index = range(1, len(naver_news)+1))
df.index.name = "No"
df.to_csv("../data/naver_news.csv", encoding = "utf-8")

driver.back()
driver.back()
driver.quit()

# %%
df
# Out:
#                                      제목
# No
# 1                      뉴진스, 얼마나 스윗한지!!!
# 2                 [포토] 뉴진스 해린 '러블리 러블리'
# 3                            뉴진스 해린, 요정
# 4                  뉴진스 해린 '눈부신 하트'[★포토]
# 5                  [포토] 뉴진스 해린 '완벽한 비율'
# 6                  [포토] 뉴진스 해린, '아름다워~'
# 7      뉴진스 'How Sweet', 스포티파이 '57계단' 껑충
# 8   ‘정통 SM’ 쇠맛의 에스파 vs ‘이지 리스닝’ 달콤한 뉴진스
# 9                 [포토] 뉴진스 해린, 고양이 귀 포즈
# 10                       [사진]뉴진스 해린, 예뻐
# 11                [포토] 뉴진스 해린, '예쁜 미소~'
# 12      뉴진스, 브랜딩과 접속사가 없네…민희진 式 근사한 원근법
# 13             [포토] 뉴진스 해린, '활짝 핀 꽃미모~'
# 14              [포토] 뉴진스 해린, '귀여워~귀여워~'
# 15                 [포토] 뉴진스 해린, 도도한 고양이
# 16                  [포토] 뉴진스 해린, 예뻐서 기절
# 17                 뉴진스 해린 '오똑한 콧날'[★포토]
# 18   [가요소식] 뉴진스 '하우 스위트' 스포티파이 일간차트 상승세
# 19                  뉴진스 해린, 갸웃? [SE★포토]
# 20              [포토]뉴진스 해린, 비주얼로 성수동 마비
